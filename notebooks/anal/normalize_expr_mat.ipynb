# %% [markdown]
# ### Notebook: Normalize Expression Data (`normalize_expr_mat.ipynb`)
#
# This notebook is dedicated to normalizing new expression data using the Binning-By-Gene method, tailored for use with the GeneRAIN models. It includes instructions and code snippets for processing your data in line with the requirements of different GeneRAIN models.

# %%
import anndata
import numpy as np
import pandas as pd
import pickle
from data.adata import Adata
from utils.config_loader import Config
import os
from data.GetBinsByGeneForNewSamples import get_bins_by_gene_for_new_samples

# %% [markdown]
# - **Selecting Binning Boundaries**:
#   - Specify the files to obtain binning boundaries for Binning-By-Gene normalization.
#   - Note: The gene set in the `coding_lncrna` model differs from other models.
#   - Set `gene_emb_name` to `'coding_lncrna'` for the `GeneRAIN.GPT_protein_coding_lncRNAs` model.
#   - Set `gene_emb_name` to `'gene2vec'` for the `GeneRAIN.GPT_Binning_By_Gene`, `GeneRAIN.BERT_Pred_Genes_Binning_By_Gene`, or `GeneRAIN.BERT_Pred_Expr_Binning_By_Gene` models.

# %%
config = Config()
# Set gene_emb_name to 'coding_lncrna' if you are preparing dataset for GeneRAIN.GPT_protein_coding_lncRNAs model
# Set gene_emb_name to 'gene2vec' if you are preparing dataset for GeneRAIN.GPT_Binning_By_Gene, 
# GeneRAIN.BERT_Pred_Genes_Binning_By_Gene or GeneRAIN.BERT_Pred_Expr_Binning_By_Gene models, as they are using gene set overlaping with gene2vec
gene_emb_name = "coding_lncrna"
if gene_emb_name == "coding_lncrna":
    samples_by_genes_subsampled_file = config.proj_path + "/data/external/ARCHS/normalize_each_gene/human_gene_v2.2_with_zero_expr_genes_bin_tot2000_coding_lncrna_0.005_subsampled.npy"
    subsampled_gene_symbol_file = config.proj_path + "/data/external/ARCHS/normalize_each_gene/human_gene_v2.2_with_zero_expr_genes_bin_tot2000_coding_lncrna_0.005_subsampled.gene_symbols.txt"
elif gene_emb_name == "gene2vec":
    samples_by_genes_subsampled_file = config.proj_path + "/data/external/ARCHS/normalize_each_gene/human_gene_v2.2_with_zero_expr_genes_bin_tot2000_gene2vec_0.005_subsampled.npy"
    subsampled_gene_symbol_file = config.proj_path + "/data/external/ARCHS/normalize_each_gene/human_gene_v2.2_with_zero_expr_genes_bin_tot2000_gene2vec_0.005_subsampled.gene_symbols.txt"

# %% [markdown]
# - **Processing Expression Matrix**:
#   - Obtain the expression matrix and the corresponding gene symbols to prepare the dataset for model input.

# %%
gene_expr_data_file = config.proj_path + "/data/examples/ReplogleWeissman2022_K562_essential.h5ad.mean_agg.pickle"
with open(gene_expr_data_file, 'rb') as f:
    adata = pickle.load(f)
# the list of sample or cell names of the matrix
cell_group_names = adata.obs_names
# the list of gene symbols of the matrix
gene_names = adata.var_names
# the expression matrix
sample_by_gene_expr_matrix = adata.X

# %% [markdown]
# - **Applying Binning-By-Gene Normalization**:
#   - Utilize the `get_bins_by_gene_for_new_samples` function to normalize the expression matrix. The function's documentation provides further details.
#
#     Parameters:
#     - samples_by_genes_subsampled_file (str): File containing the subsampled genes by samples matrix.
#     - subsampled_gene_symbol_file (str): File containing gene symbols corresponding to the rows of the subsampled matrix.
#     - gene_by_sample_expr_mat (numpy.ndarray): Gene by sample expression matrix to be processed and binned.
#     - quantified_gene_list (list or numpy.ndarray): List of gene symbols corresponding to the rows of gene_by_sample_expr_mat.
#     - output_prefix (str, optional): Prefix for output files such as statistics dataframe. None for no output.
#     - num_gene_bin (int, optional): The number of bins to be used for discretization. Defaults to 2000.
#     - min_total_count (int, optional): Minimum total count to consider a sample as valid. Defaults to -1.
#
#     Returns:
#     - gene_by_sample_mat_binned (numpy.ndarray): Binned version of the input gene_by_sample_expr_mat.
#     - bool_for_if_samples_included_in_returned_mat (numpy.ndarray): Boolean array indicating if the samples in the input matrix are included in the processed matrix.
#     - gene_exist_in_subsampled (numpy.ndarray): Boolean array indicating which genes from the input matrix are present in the subsampled matrix.
#     - stats_df (pandas.DataFrame): DataFrame containing statistics for each sample in the input matrix.
#
#     Notes:
#     The function uses a subsampled gene expression dataset to bin the input gene expression dataset. The binned values correspond to the discretized expression values of the genes, based on the subsampled data.

# %%
gene_by_sample_mat_binned, bool_for_if_samples_included_in_returned_mat, gene_exist_in_subsampled, stats_df = get_bins_by_gene_for_new_samples(samples_by_genes_subsampled_file, 
                                                                                                                                                 subsampled_gene_symbol_file, 
                                                                                                                                                 gene_by_sample_expr_mat=sample_by_gene_expr_matrix.T, 
                                                                                                                                                 quantified_gene_list=gene_names, 
                                                                                                                                                 output_prefix=None, 
                                                                                                                                                 num_gene_bin= 2000,  
                                                                                                                                                 min_total_count=-1)
# Out:
# genes_by_samples_subsampled_mat shape (31769, 2054)
# processing samples from 0 to 4
# processing samples from 10 to 14
# processing samples from 20 to 24
# processing samples from 30 to 34
# processing samples from 40 to 44
# processing samples from 50 to 54
# processing samples from 60 to 64
# processing samples from 70 to 74
# processing samples from 80 to 84
# processing samples from 90 to 94
# processing samples from 100 to 104
# processing samples from 110 to 114
# processing samples from 120 to 124
# processing samples from 130 to 134
# processing samples from 140 to 144
# processing samples from 150 to 154
# processing samples from 160 to 164
# processing samples from 170 to 174
# processing samples from 180 to 184
# processing samples from 190 to 194
# processing samples from 200 to 204
# processing samples from 210 to 214
# processing samples from 220 to 224
# processing samples from 230 to 234
# processing samples from 240 to 244
# processing samples from 250 to 254
# processing samples from 260 to 264
# processing samples from 270 to 274
# processing samples from 280 to 284
# processing samples from 290 to 294
# processing samples from 300 to 304
# processing samples from 310 to 314
# processing samples from 320 to 324
# processing samples from 330 to 334
# processing samples from 340 to 344
# processing samples from 350 to 354
# processing samples from 360 to 364
# processing samples from 370 to 374
# processing samples from 380 to 384
# processing samples from 390 to 394
# processing samples from 400 to 404
# processing samples from 410 to 414
# processing samples from 420 to 424
# processing samples from 430 to 434
# processing samples from 440 to 444
# processing samples from 450 to 454
# processing samples from 460 to 464
# processing samples from 470 to 474
# processing samples from 480 to 484
# processing samples from 490 to 494
# processing samples from 500 to 504
# processing samples from 510 to 514
# processing samples from 520 to 524
# processing samples from 530 to 534
# processing samples from 540 to 544
# processing samples from 550 to 554
# processing samples from 560 to 564
# processing samples from 570 to 574
# processing samples from 580 to 584
# processing samples from 590 to 594
# processing samples from 600 to 604
# processing samples from 610 to 614
# processing samples from 620 to 624
# processing samples from 630 to 634
# processing samples from 640 to 644
# processing samples from 650 to 654
# processing samples from 660 to 664
# processing samples from 670 to 674
# processing samples from 680 to 684
# processing samples from 690 to 694
# processing samples from 700 to 704
# processing samples from 710 to 714
# processing samples from 720 to 724
# processing samples from 730 to 734
# processing samples from 740 to 744
# processing samples from 750 to 754
# processing samples from 760 to 764
# processing samples from 770 to 774
# processing samples from 780 to 784
# processing samples from 790 to 794
# processing samples from 800 to 804
# processing samples from 810 to 814
# processing samples from 820 to 824
# processing samples from 830 to 834
# processing samples from 840 to 844
# processing samples from 850 to 854
# processing samples from 860 to 864
# processing samples from 870 to 874
# processing samples from 880 to 884
# processing samples from 890 to 894
# processing samples from 900 to 904
# processing samples from 910 to 914
# processing samples from 920 to 924
# processing samples from 930 to 934
# processing samples from 940 to 944
# processing samples from 950 to 954
# processing samples from 960 to 964
# processing samples from 970 to 974
# processing samples from 980 to 984
# processing samples from 990 to 994
# processing samples from 1000 to 1004
# processing samples from 1010 to 1014
# processing samples from 1020 to 1024
# processing samples from 1030 to 1034
# processing samples from 1040 to 1044
# processing samples from 1050 to 1054
# processing samples from 1060 to 1064
# processing samples from 1070 to 1074
# processing samples from 1080 to 1084
# processing samples from 1090 to 1094
# processing samples from 1100 to 1104
# processing samples from 1110 to 1114
# processing samples from 1120 to 1124
# processing samples from 1130 to 1134
# processing samples from 1140 to 1144
# processing samples from 1150 to 1154
# processing samples from 1160 to 1164
# processing samples from 1170 to 1174
# processing samples from 1180 to 1184
# processing samples from 1190 to 1194
# processing samples from 1200 to 1204
# processing samples from 1210 to 1214
# processing samples from 1220 to 1224
# processing samples from 1230 to 1234
# processing samples from 1240 to 1244
# processing samples from 1250 to 1254
# processing samples from 1260 to 1264
# processing samples from 1270 to 1274
# processing samples from 1280 to 1284
# processing samples from 1290 to 1294
# processing samples from 1300 to 1304
# processing samples from 1310 to 1314
# processing samples from 1320 to 1324
# processing samples from 1330 to 1334
# processing samples from 1340 to 1344
# processing samples from 1350 to 1354
# processing samples from 1360 to 1364
# processing samples from 1370 to 1374
# processing samples from 1380 to 1384
# processing samples from 1390 to 1394
# processing samples from 1400 to 1404
# processing samples from 1410 to 1414
# processing samples from 1420 to 1424
# processing samples from 1430 to 1434
# processing samples from 1440 to 1444
# processing samples from 1450 to 1454
# processing samples from 1460 to 1464
# processing samples from 1470 to 1474
# processing samples from 1480 to 1484
# processing samples from 1490 to 1494
# processing samples from 1500 to 1504
# processing samples from 1510 to 1514
# processing samples from 1520 to 1524
# processing samples from 1530 to 1534
# processing samples from 1540 to 1544
# processing samples from 1550 to 1554
# processing samples from 1560 to 1564
# processing samples from 1570 to 1574
# processing samples from 1580 to 1584
# processing samples from 1590 to 1594
# processing samples from 1600 to 1604
# processing samples from 1610 to 1614
# processing samples from 1620 to 1624
# processing samples from 1630 to 1634
# processing samples from 1640 to 1644
# processing samples from 1650 to 1654
# processing samples from 1660 to 1664
# processing samples from 1670 to 1674
# processing samples from 1680 to 1684
# processing samples from 1690 to 1694
# processing samples from 1700 to 1704
# processing samples from 1710 to 1714
# processing samples from 1720 to 1724
# processing samples from 1730 to 1734
# processing samples from 1740 to 1744
# processing samples from 1750 to 1754
# processing samples from 1760 to 1764
# processing samples from 1770 to 1774
# processing samples from 1780 to 1784
# processing samples from 1790 to 1794
# processing samples from 1800 to 1804
# processing samples from 1810 to 1814
# processing samples from 1820 to 1824
# processing samples from 1830 to 1834
# processing samples from 1840 to 1844
# processing samples from 1850 to 1854
# processing samples from 1860 to 1864
# processing samples from 1870 to 1874
# processing samples from 1880 to 1884
# processing samples from 1890 to 1894
# processing samples from 1900 to 1904
# processing samples from 1910 to 1914
# processing samples from 1920 to 1924
# processing samples from 1930 to 1934
# processing samples from 1940 to 1944
# processing samples from 1950 to 1954
# processing samples from 1960 to 1964
# processing samples from 1970 to 1974
# processing samples from 1980 to 1984
# processing samples from 1990 to 1994
# processing samples from 2000 to 2004
# processing samples from 2010 to 2014
# processing samples from 2020 to 2024
# processing samples from 2030 to 2034
# processing samples from 2040 to 2044
# processing samples from 2050 to 2054
# processing samples from 2060 to 2064
# processing samples from 2070 to 2074
# processing samples from 2080 to 2084
# processing samples from 2090 to 2094
# processing samples from 2100 to 2104
# processing samples from 2110 to 2114
# processing samples from 2120 to 2124
# processing samples from 2130 to 2134
# processing samples from 2140 to 2144
# processing samples from 2150 to 2154
# processing samples from 2160 to 2164
# processing samples from 2170 to 2174
# processing samples from 2180 to 2184
# processing samples from 2190 to 2194
# processing samples from 2200 to 2204
# processing samples from 2210 to 2214
# processing samples from 2220 to 2224
# processing samples from 2230 to 2234
# processing samples from 2240 to 2244
# processing samples from 2250 to 2254
# processing samples from 2260 to 2264
# processing samples from 2270 to 2272

# %% [markdown]
# - **Save the normalized output**
#     - Save the normalized output as an Adata object and export it in both `.pkl` and `.tsv` formats for subsequent use.

# %%
binned_adata = Adata(np.array(cell_group_names)[bool_for_if_samples_included_in_returned_mat], 
                     np.array(gene_names)[gene_exist_in_subsampled],
                     gene_by_sample_mat_binned.T[:,gene_exist_in_subsampled]
                    )

output_pickle_file = config.proj_path + f"/data/examples/ReplogleWeissman2022_K562_essential.h5ad.mean_agg.{gene_emb_name}.binned.pkl"
with open(output_pickle_file, 'wb') as f:
    pickle.dump(binned_adata, f)
print(f"expr data saved to {output_pickle_file}.")

output_tsv_file = config.proj_path + f"/data/examples/ReplogleWeissman2022_K562_essential.h5ad.mean_agg.{gene_emb_name}.binned.tsv"
binned_adata.save_matrix_to_tsv(output_tsv_file)
print(f'Data saved to {output_tsv_file}.')
# Out:
# expr data saved to /g/data/yr31/zs2131/tasks/2023/RNA_expr_net/DeepGeneNet//data/examples/ReplogleWeissman2022_K562_essential.h5ad.mean_agg.coding_lncrna.binned.pkl!
# Data saved to /g/data/yr31/zs2131/tasks/2023/RNA_expr_net/DeepGeneNet//data/examples/ReplogleWeissman2022_K562_essential.h5ad.mean_agg.coding_lncrna.binned.tsv
